# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt
import yahoo_fin.stock_info as si

# %%
tickers = ['FB', 'AMZN', 'AAPL', 'MSFT', 'NFLX', 'GOOGL']
mydata = pd.DataFrame()
for t in tickers:
    mydata[t] = wb.DataReader(t, data_source='yahoo', start='1995-1-1')['Adj Close']

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2355 entries, 2012-05-18 to 2021-09-27
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FB      2355 non-null   float64
#  1   AMZN    2355 non-null   float64
#  2   AAPL    2355 non-null   float64
#  3   MSFT    2355 non-null   float64
#  4   NFLX    2355 non-null   float64
#  5   GOOGL   2355 non-null   float64
# dtypes: float64(6)
# memory usage: 128.8 KB

# %%
mydata.head()
# Out:
#                    FB        AMZN       AAPL       MSFT       NFLX       GOOGL
# Date
# 2012-05-18  38.230000  213.850006  16.264032  24.047728   9.994286  300.500488
# 2012-05-21  34.029999  218.110001  17.211582  24.442087  10.248571  307.362366
# 2012-05-22  31.000000  215.330002  17.079418  24.450296   9.672857  300.700714
# 2012-05-23  32.000000  217.279999  17.496151  23.916271  10.272857  305.035034
# 2012-05-24  33.029999  215.240005  17.335464  23.883410  10.038571  302.132141

# %%
mydata.tail()
# Out:
#                     FB         AMZN        AAPL        MSFT        NFLX  \
# Date
# 2021-09-21  357.480011  3343.629883  143.429993  294.799988  573.140015
# 2021-09-22  343.209991  3380.050049  145.850006  298.579987  590.650024
# 2021-09-23  345.959991  3416.000000  146.830002  299.559998  593.260010
# 2021-09-24  352.959991  3425.520020  146.919998  299.350006  592.390015
# 2021-09-27  353.579987  3405.800049  145.369995  294.170013  592.640015
#
#                   GOOGL
# Date
# 2021-09-21  2780.659912
# 2021-09-22  2805.669922
# 2021-09-23  2824.320068
# 2021-09-24  2844.300049
# 2021-09-27  2821.439941

# %%
mydata.iloc[0]
# Out:
# FB        38.230000
# AMZN     213.850006
# AAPL      16.264032
# MSFT      24.047728
# NFLX       9.994286
# GOOGL    300.500488
# Name: 2012-05-18 00:00:00, dtype: float64

# %%
#Normalized all equities to 100
(mydata / mydata.iloc[0] * 100).plot(figsize = (15, 6));
plt.show()

# %%
#Not normalized to 100
mydata.plot(figsize=(15, 6))
plt.show()

# %%
returns = (mydata / mydata.shift(1)) - 1
returns.head()
# Out:
#                   FB      AMZN      AAPL      MSFT      NFLX     GOOGL
# Date
# 2012-05-18       NaN       NaN       NaN       NaN       NaN       NaN
# 2012-05-21 -0.109861  0.019920  0.058260  0.016399  0.025443  0.022835
# 2012-05-22 -0.089039 -0.012746 -0.007679  0.000336 -0.056175 -0.021674
# 2012-05-23  0.032258  0.009056  0.024400 -0.021841  0.062029  0.014414
# 2012-05-24  0.032187 -0.009389 -0.009184 -0.001374 -0.022806 -0.009517

# %%
annual_returns = returns.mean() * 250
annual_returns
# Out:
# FB       0.302814
# AMZN     0.338337
# AAPL     0.272754
# MSFT     0.298905
# NFLX     0.539924
# GOOGL    0.269355
# dtype: float64

# %%
weights = np.array([0.16, 0.16, 0.16, 0.16, 0.16, 0.16])

# %%
np.dot(annual_returns, weights)
# Out:
# 0.3235342893758975

# %%
pfolio_1 = str(round(np.dot(annual_returns, weights), 5) * 100) + ' %'
print (pfolio_1)
# Out:
# 32.353 %

# %%
weights_2 = np.array([.4, .2, .1, .1, .1, .1])

# %%
pfolio_2 = str(round(np.dot(annual_returns, weights_2), 5) * 100) + ' %'
print (pfolio_1)
print (pfolio_2)
# Out:
# 32.353 %
# 32.689 %
