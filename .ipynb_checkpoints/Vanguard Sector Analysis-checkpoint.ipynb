# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt
import yahoo_fin.stock_info as si

# %%
tickers = ['FB', 'AMZN', 'AAPL', 'MSFT', 'NFLX', 'GOOGL']
mydata = pd.DataFrame()
for t in tickers:
    mydata[t] = wb.DataReader(t, data_source='yahoo', start='1995-1-1')['Adj Close']

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2364 entries, 2012-05-18 to 2021-10-08
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FB      2364 non-null   float64
#  1   AMZN    2364 non-null   float64
#  2   AAPL    2364 non-null   float64
#  3   MSFT    2364 non-null   float64
#  4   NFLX    2364 non-null   float64
#  5   GOOGL   2364 non-null   float64
# dtypes: float64(6)
# memory usage: 129.3 KB

# %%
mydata.head()
# Out:
#                    FB        AMZN       AAPL       MSFT       NFLX       GOOGL
# Date
# 2012-05-18  38.230000  213.850006  16.264032  24.047724   9.994286  300.500488
# 2012-05-21  34.029999  218.110001  17.211573  24.442087  10.248571  307.362366
# 2012-05-22  31.000000  215.330002  17.079411  24.450306   9.672857  300.700714
# 2012-05-23  32.000000  217.279999  17.496157  23.916277  10.272857  305.035034
# 2012-05-24  33.029999  215.240005  17.335466  23.883410  10.038571  302.132141

# %%
mydata.tail()
# Out:
#                     FB         AMZN        AAPL        MSFT        NFLX  \
# Date
# 2021-10-04  326.230011  3189.780029  139.139999  283.109985  603.349976
# 2021-10-05  332.959991  3221.000000  141.110001  288.760010  634.809998
# 2021-10-06  333.640015  3262.010010  142.000000  293.109985  639.099976
# 2021-10-07  329.220001  3302.429932  143.289993  294.850006  631.849976
# 2021-10-08  330.049988  3288.620117  142.899994  294.850006  632.659973
#
#                   GOOGL
# Date
# 2021-10-04  2673.189941
# 2021-10-05  2720.459961
# 2021-10-06  2751.300049
# 2021-10-07  2784.500000
# 2021-10-08  2795.709961

# %%
mydata.iloc[0]
# Out:
# FB        38.230000
# AMZN     213.850006
# AAPL      16.264032
# MSFT      24.047724
# NFLX       9.994286
# GOOGL    300.500488
# Name: 2012-05-18 00:00:00, dtype: float64

# %%
#Normalized all equities to 100
(mydata / mydata.iloc[0] * 100).plot(figsize = (15, 6));
plt.show()

# %%
#Not normalized to 100
mydata.plot(figsize=(15, 6))
plt.show()

# %%
returns = (mydata / mydata.shift(1)) - 1
returns.head()
# Out:
#                   FB      AMZN      AAPL      MSFT      NFLX     GOOGL
# Date
# 2012-05-18       NaN       NaN       NaN       NaN       NaN       NaN
# 2012-05-21 -0.109861  0.019920  0.058260  0.016399  0.025443  0.022835
# 2012-05-22 -0.089039 -0.012746 -0.007679  0.000336 -0.056175 -0.021674
# 2012-05-23  0.032258  0.009056  0.024400 -0.021841  0.062029  0.014414
# 2012-05-24  0.032187 -0.009389 -0.009184 -0.001374 -0.022806 -0.009517

# %%
annual_returns = returns.mean() * 250
annual_returns
# Out:
# FB       0.294617
# AMZN     0.333450
# AAPL     0.269993
# MSFT     0.298177
# NFLX     0.545010
# GOOGL    0.267522
# dtype: float64

# %%
weights = np.array([0.16, 0.16, 0.16, 0.16, 0.16, 0.16])

# %%
np.dot(annual_returns, weights)
# Out:
# 0.3214028812731953

# %%
pfolio_1 = str(round(np.dot(annual_returns, weights), 5) * 100) + ' %'
print (pfolio_1)
# Out:
# 32.14 %

# %%
weights_2 = np.array([.4, .2, .1, .1, .1, .1])

# %%
pfolio_2 = str(round(np.dot(annual_returns, weights_2), 5) * 100) + ' %'
print (pfolio_1)
print (pfolio_2)
# Out:
# 32.14 %
# 32.261 %
