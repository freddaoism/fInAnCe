# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt
import yahoo_fin.stock_info as si

# %%
tickers = ['^GSPC', '^IXIC', '^GDAXI', '^N225']

ind_data = pd.DataFrame()

for t in tickers:
    ind_data[t] = wb.DataReader(t, data_source='yahoo', start='1997-1-1')['Adj Close']

# %%
ind_data.head()
# Out:
#                  ^GSPC        ^IXIC       ^GDAXI         ^N225
# Date
# 1997-01-02  737.010010  1280.699951  2820.810059           NaN
# 1997-01-03  748.030029  1310.680054  2863.260010           NaN
# 1997-01-06  747.650024  1316.400024  2890.199951  19446.000000
# 1997-01-07  753.229980  1327.729980  2876.340088  18896.189453
# 1997-01-08  748.409973  1320.349976  2904.080078  18680.380859

# %%
ind_data.tail()
# Out:
#                   ^GSPC         ^IXIC        ^GDAXI         ^N225
# Date
# 2021-09-23  4448.979980  15052.240234  15643.969727           NaN
# 2021-09-24  4455.479980  15047.700195  15531.750000  30248.810547
# 2021-09-27  4443.109863  14969.969727  15573.879883  30240.060547
# 2021-09-28  4352.629883  14546.679688  15248.559570  30183.960938
# 2021-09-29  4359.459961  14512.440430  15365.269531  29544.289062

# %%
#Normalizing and plotting sp500, nasdaq, gdaxi -> german index, and n225 -> japan index
(ind_data / ind_data.iloc[0] * 100).plot(figsize=(15, 6));
plt.show()

# %%
ind_returns = (ind_data/ ind_data.shift(1))- 1

ind_returns.tail()
# Out:
#                ^GSPC     ^IXIC    ^GDAXI     ^N225
# Date
# 2021-09-23  0.012135  0.010431  0.008850       NaN
# 2021-09-24  0.001461 -0.000302 -0.007173       NaN
# 2021-09-27 -0.002776 -0.005166  0.002713 -0.000289
# 2021-09-28 -0.020364 -0.028276 -0.020889 -0.001855
# 2021-09-29  0.001569 -0.002354  0.007654 -0.021192

# %%
annual_ind_returns = ind_returns.mean() * 250 
annual_ind_returns
# Out:
# ^GSPC     0.090451
# ^IXIC     0.128757
# ^GDAXI    0.080790
# ^N225     0.005383
# dtype: float64

# %%
#Comparing stock to stock indexes
tickers = ['^GSPC', '^IXIC', '^GDAXI', 'CCL']

data_2 = pd.DataFrame()

for t in tickers:
    data_2[t] = wb.DataReader(t, data_source='yahoo', start='2007-1-1')['Adj Close']

# %%
data_2.tail()
# Out:
#                   ^GSPC         ^IXIC        ^GDAXI        CCL
# Date
# 2021-09-23  4448.979980  15052.240234  15643.969727  24.690001
# 2021-09-24  4455.479980  15047.700195  15531.750000  25.440001
# 2021-09-27  4443.109863  14969.969727  15573.879883  26.379999
# 2021-09-28  4352.629883  14546.679688  15248.559570  26.170000
# 2021-09-29  4359.459961  14512.440430  15365.269531  25.520000

# %%
(data_2 / data_2.iloc[0] * 100).plot(figsize=(15,6));
plt.show()
